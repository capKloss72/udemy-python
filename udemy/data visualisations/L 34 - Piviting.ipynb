# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randn
from IPython.display import YouTubeVideo
from pandas_datareader import data, wb
import pandas_datareader as pdweb
import datetime
import seaborn as sns
import matplotlib.pyplot as plt 
from seaborn.regression import coefplot
import sys

# %%
# Lets create some data to play with:

# Note: It is not necessary to understand how this dataset was made to understand this Lecture.

#import pandas testing utility
import pandas.util.testing as tm; tm.N = 3

#Create a unpivoted function
def unpivot(frame):
    N, K = frame.shape
    
    data = {'value' : frame.values.ravel('F'),
            'variable' : np.asarray(frame.columns).repeat(N),
            'date' : np.tile(np.asarray(frame.index), K)}
    
    # Return the DataFrame
    return DataFrame(data, columns=['date', 'variable', 'value'])

#Set the DataFrame we'll be using
dframe = unpivot(tm.makeTimeDataFrame())

# %%
dframe
# Out:
#          date variable     value
# 0  2000-01-03        A  2.192301
# 1  2000-01-04        A -0.530608
# 2  2000-01-05        A  0.251629
# 3  2000-01-03        B -1.130715
# 4  2000-01-04        B  1.117702
# 5  2000-01-05        B -0.353116
# 6  2000-01-03        C -0.226130
# 7  2000-01-04        C -1.150922
# 8  2000-01-05        C -1.350431
# 9  2000-01-03        D -0.373136
# 10 2000-01-04        D  0.492362
# 11 2000-01-05        D -0.592315

# %%
dframe_piv = dframe.pivot('date','variable','value')

# %%
dframe_piv
# Out:
# variable           A         B         C         D
# date
# 2000-01-03  2.192301 -1.130715 -0.226130 -0.373136
# 2000-01-04 -0.530608  1.117702 -1.150922  0.492362
# 2000-01-05  0.251629 -0.353116 -1.350431 -0.592315

# %%
2.192301+-1.130715+-0.226130+-0.373136
# Out:
# 0.4623200000000002

# %%
training = pd.read_excel('Tym Training 5 Dams 2018.xlsx')
training
# Out:
#                W/C                                             Monday  \
# Week 1  2018-01-08  Commute + 1 x Reverse Street OR\nZwift 2x15 FT...
# Week 2  2018-01-15  Commute + 1 x Reverse Street OR\nZwift 2x15 FT...
# Week 3  2018-01-22  Commute + 1 x Reverse Street OR\nZwift 2x15 FT...
# Week 4  2018-01-29                                            Commute
# Week 5  2018-02-05  Commute + 1 x Reverse Street + 1 x Stock Road ...
# Week 6  2018-02-12  Commute + 1 x Reverse Street + 1 x Stock Road ...
# Week 7  2018-02-19  Commute + 1 x Reverse Street + 1 x Stock Road ...
# Week 8  2018-02-26                                            Commute
# Week 9  2018-03-05  Commute + 1 x Reverse Street + 2 x Stock Road ...
# Week 10 2018-03-12  Commute + 1 x Reverse Street + 2 x Stock Road ...
# Week 11 2018-03-19  Commute + 1 x Reverse Street + 2 x Stock Road ...
# Week 12 2018-03-26                                            Commute
#
# ...

# %%
training_piv = training.pivot('W/C','Friday')

# %%
training_piv
# Out:
#              Monday  \
# Friday      Commute
# W/C
# 2018-01-08     None
# 2018-01-15     None
# 2018-01-22     None
# 2018-01-29  Commute
# 2018-02-05     None
# 2018-02-12     None
# 2018-02-19     None
# 2018-02-26  Commute
# 2018-03-05     None
# 2018-03-12     None
# 2018-03-19     None
# 2018-03-26  Commute
#
#                                                                                          \
# Friday     Commute + 1 x Reverse Street + 1 x Stock Road OR\nZwift 2x15 FTP Intervals\n
# W/C
# 2018-01-08                                               None
# 2018-01-15                                               None
# 2018-01-22                                               None
# 2018-01-29                                               None
# 2018-02-05  Commute + 1 x Reverse Street + 1 x Stock Road ...
# 2018-02-12                                               None
# 2018-02-19                                               None
# ...
