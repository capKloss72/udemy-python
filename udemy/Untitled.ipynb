# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_clipboard()

# %%
df.columns = ['Assignee','Epic','Boulder','User Story']

# %%
df
# Out:
#                 Assignee                                               Epic  \
# 0             Joel Guest  E4 - We understand the business model and what...
# 1             Joel Guest  E4 - We understand the business model and what...
# 2             Joel Guest  E4 - We understand the business model and what...
# 3             Joel Guest  E4 - We understand the business model and what...
# 4             Joel Guest  E4 - We understand the business model and what...
# 5             Joel Guest  E4 - We understand the business model and what...
# 6             Joel Guest  E4 - We understand the business model and what...
# 7             Joel Guest  E5 - We can easily and scaleably help AMO impr...
# 8             Garry Dack  E5 - We can easily and scaleably help AMO impr...
# 9             Garry Dack  E5 - We can easily and scaleably help AMO impr...
# 10          Dhruti Patel  E5 - We can easily and scaleably help AMO impr...
# ...
